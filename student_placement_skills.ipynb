# %% [markdown]
# <a href="https://colab.research.google.com/github/2400033216/student-placement-analysis/blob/main/student_placement_skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("Student_Placement_Skills_2025.csv")
df
# Out:
#      Student_ID  Gender  Age            Degree  CGPA  Internships_Count  \
# 0             1    Male   19          Business  2.56                  3
# 1             2  Female   27       Engineering  3.66                  0
# 2             3    Male   26      Data Science  3.73                  0
# 3             4    Male   18  Computer Science  2.21                  2
# 4             5    Male   20          Business  2.59                  3
# ..          ...     ...  ...               ...   ...                ...
# 595         596  Female   22          Business  2.52                  3
# 596         597    Male   19      Data Science  2.86                  3
# 597         598    Male   28      Data Science  2.71                  0
# 598         599    Male   26       Engineering  2.97                  3
# 599         600  Female   19       Engineering  2.13                  4
#
#      Projects_Count  Certifications_Count  Technical_Skills_Score_100  \
# ...

# %% [markdown]
# # New Section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Student_ID                      600 non-null    int64
#  1   Gender                          600 non-null    object
#  2   Age                             600 non-null    int64
#  3   Degree                          600 non-null    object
#  4   CGPA                            600 non-null    float64
#  5   Internships_Count               600 non-null    int64
#  6   Projects_Count                  600 non-null    int64
#  7   Certifications_Count            600 non-null    int64
#  8   Technical_Skills_Score_100      600 non-null    int64
#  9   Communication_Skills_Score_100  600 non-null    int64
#  10  Aptitude_Test_Score_100         600 non-null    int64
#  11  Placement_Offer                 600 non-null    object
# ...

# %%
df.shape
# Out:
# (600, 13)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Degree', 'CGPA', 'Internships_Count',
#        'Projects_Count', 'Certifications_Count', 'Technical_Skills_Score_100',
#        'Communication_Skills_Score_100', 'Aptitude_Test_Score_100',
#        'Placement_Offer', 'Salary_Offered_USD'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Student_ID                        0
# Gender                            0
# Age                               0
# Degree                            0
# CGPA                              0
# Internships_Count                 0
# Projects_Count                    0
# Certifications_Count              0
# Technical_Skills_Score_100        0
# Communication_Skills_Score_100    0
# Aptitude_Test_Score_100           0
# Placement_Offer                   0
# Salary_Offered_USD                0
# dtype: int64

# %%
df.groupby("Placement_Offer")["CGPA"].mean()
# Out:
# Placement_Offer
# No     3.050376
# Yes    2.938837
# Name: CGPA, dtype: float64

# %%
df.groupby("Placement_Offer")["CGPA"].mean()
df.groupby("Projects_Count")["Internships_Count"].mean()
df.groupby("Gender")["Projects_Count"].mean()
# Out:
# Gender
# Female    5.003185
# Male      5.255245
# Name: Projects_Count, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="Placement_Offer", y="CGPA")
plt.title("CGPA vs Placement")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="Placement_Offer", y="Gender")
plt.title("Gender vs Placement")
plt.show()

# %%
import matplotlib.pyplot as plt

# Example plot
plt.plot([50],[20])
plt.savefig("my_plot.png")  # Save as PNG
plt.close()

# %%
from google.colab import files

files.download("my_plot.png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Create the plot
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="Placement_Offer", y="CGPA")
plt.title("CGPA vs Placement")

# Save the plot as a PNG
plt.savefig("cgpa_vs_placement.png")  # This saves the file in Colab's environment

# Download the file to your local machine
files.download("cgpa_vs_placement.png")

# Optional: show the plot in notebook as well
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Create the plot
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="Placement_Offer", y="Gender")
plt.title("Gender vs Placement")

# Save the plot as a PNG
plt.savefig("gender_vs_placement.png")  # This saves the file in Colab's environment

# Download the file to your local machine
files.download("gender_vs_placement.png")

# Optional: show the plot in notebook as well
plt.show()
